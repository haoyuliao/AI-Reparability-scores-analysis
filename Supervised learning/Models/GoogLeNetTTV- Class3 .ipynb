# %%
# %matplotlib inline
#Reference from https://pytorch.org/

# %%
from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy

plt.ion()   # interactive mode

# %%
# Data augmentation and normalization for training
# Just normalization for validation
'''
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}
'''
data_transforms = {
    'train': transforms.Compose([
        #transforms.RandomResizedCrop(224),
        transforms.Resize([224, 224]),
        transforms.RandomHorizontalFlip(),
        transforms.RandomVerticalFlip(),
        transforms.RandomRotation(180),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize([224, 224]),
        #transforms.Resize(256),
        #transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}


data_transforms = {
    'train': transforms.Compose([
        transforms.Resize([224, 224]),
        transforms.RandomHorizontalFlip(),
        transforms.RandomVerticalFlip(),
        transforms.RandomRotation(180),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize([224, 224]),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}


data_dir = '../AddMoreData061823/Class3/TTV'
l = []
l.append(datasets.ImageFolder(os.path.join(data_dir, 'train'), data_transforms['train']))
l.append(datasets.ImageFolder(os.path.join(data_dir, 'train'), data_transforms['train']))
l.append(datasets.ImageFolder(os.path.join(data_dir, 'train'), data_transforms['train']))
l.append(datasets.ImageFolder(os.path.join(data_dir, 'train'), data_transforms['train']))
#l.append(datasets.ImageFolder(os.path.join(data_dir, 'test'), data_transforms['test']))
image_datasetss = torch.utils.data.ConcatDataset(l)
image_datasets = {}
image_datasets['train'] = image_datasetss
image_datasets['test'] = datasets.ImageFolder(os.path.join(data_dir, 'test'), data_transforms['test'])
image_datasets['val'] = datasets.ImageFolder(os.path.join(data_dir, 'val'), data_transforms['test'])
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=5,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'test', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'test', 'val']}
class_names = image_datasets['test'].classes
print(class_names)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

print(len( image_datasets['train']))
print(len( image_datasets['val']))
print(len( image_datasets['test']))
# Out:
# ['0', '1', '2']
# 3016
# 93
# 98

# %% [markdown]
# Visualize a few images
# ^^^^^^^^^^^^^^^^^^^^^^
# Let's visualize a few training images so as to understand the data
# augmentations.

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs+1):
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    #print(outputs)
                    #print(labels)
                    loss = criterion(outputs, labels)
    
                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %% [markdown]
# Visualizing the model predictions
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# Generic function to display predictions for a few images

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['test']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)

            m = nn.Softmax(dim=1)
            proOutput = m(outputs)
            pros = proOutput.detach().cpu().numpy()
            #print(pros)
            #_, preds = torch.max(outputs, 1)
            #pro = torch.max(proOutput, dim=1)[0]
            #_, predsmin = torch.min(outputs, 1)
            #promin = torch.min(proOutput, dim=1)[0]

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                #ax.set_title('predicted: %s with %s probabilities' %(class_names[preds[j]], round(pro[j].item(),4)))
                print('Actual label: %s' %(class_names[labels[j].item()]))
                for jj in range(3):
                    print('predicted: %s with %s probabilities' %(class_names[jj], round(pros[j][jj],4)))
                #print('predicted: %s with %s probabilities' %(class_names[1], round(pros[j][1],4)))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
                
        model.train(mode=was_training)

#visualize_model(model_ft)

# %%
model_ft = models.googlenet(pretrained=True) #load googlenet.

num_ftrs = model_ft.fc.in_features

# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, 3)

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %% [markdown]
# Train and evaluate
# ^^^^^^^^^^^^^^^^^^
#
# It should take around 15-25 min on CPU. On GPU though, it takes less than a
# minute.

# %%
ep = 100
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=ep)
# Out:
# Epoch 1/100
# ----------
# train Loss: 0.7052 Acc: 0.7268
# val Loss: 0.7131 Acc: 0.6989
#
# Epoch 2/100
# ----------
# train Loss: 0.5496 Acc: 0.7898
# val Loss: 0.6387 Acc: 0.7527
#
# Epoch 3/100
# ----------
# train Loss: 0.4376 Acc: 0.8372
# val Loss: 0.5791 Acc: 0.7849
#
# Epoch 4/100
# ----------
# train Loss: 0.3732 Acc: 0.8568
# val Loss: 0.6227 Acc: 0.7957
#
# Epoch 5/100
# ----------
# train Loss: 0.3087 Acc: 0.8813
# val Loss: 0.5227 Acc: 0.7957
#
# Epoch 6/100
# ----------
# train Loss: 0.2409 Acc: 0.9101
# val Loss: 0.6868 Acc: 0.7957
#
# Epoch 7/100
# ----------
# train Loss: 0.2074 Acc: 0.9224
# val Loss: 0.5322 Acc: 0.7957
#
# Epoch 8/100
# ----------
# train Loss: 0.1566 Acc: 0.9469
# val Loss: 0.4613 Acc: 0.8172
#
# Epoch 9/100
# ----------
# train Loss: 0.1263 Acc: 0.9609
# val Loss: 0.4781 Acc: 0.8817
#
# Epoch 10/100
# ----------
# train Loss: 0.1293 Acc: 0.9566
# val Loss: 0.4266 Acc: 0.8172
#
# Epoch 11/100
# ----------
# train Loss: 0.1038 Acc: 0.9708
# val Loss: 0.4324 Acc: 0.8602
#
# Epoch 12/100
# ----------
# train Loss: 0.1075 Acc: 0.9702
# val Loss: 0.4449 Acc: 0.8602
#
# Epoch 13/100
# ----------
# train Loss: 0.0893 Acc: 0.9702
# val Loss: 0.4056 Acc: 0.8387
#
# Epoch 14/100
# ----------
# train Loss: 0.1083 Acc: 0.9632
# val Loss: 0.4404 Acc: 0.8602
#
# Epoch 15/100
# ----------
# train Loss: 0.1034 Acc: 0.9649
# val Loss: 0.4500 Acc: 0.8602
#
# Epoch 16/100
# ----------
# train Loss: 0.0782 Acc: 0.9784
# val Loss: 0.4828 Acc: 0.8495
#
# Epoch 17/100
# ----------
# train Loss: 0.0899 Acc: 0.9715
# val Loss: 0.4460 Acc: 0.8280
#
# Epoch 18/100
# ----------
# train Loss: 0.0829 Acc: 0.9748
# val Loss: 0.4248 Acc: 0.8602
#
# Epoch 19/100
# ----------
# train Loss: 0.0930 Acc: 0.9728
# val Loss: 0.4322 Acc: 0.8710
#
# Epoch 20/100
# ----------
# train Loss: 0.0971 Acc: 0.9728
# val Loss: 0.4569 Acc: 0.8710
#
# Epoch 21/100
# ----------
# train Loss: 0.0854 Acc: 0.9761
# val Loss: 0.4649 Acc: 0.8280
#
# Epoch 22/100
# ----------
# train Loss: 0.0860 Acc: 0.9758
# val Loss: 0.4177 Acc: 0.8710
#
# Epoch 23/100
# ----------
# train Loss: 0.0868 Acc: 0.9738
# val Loss: 0.4325 Acc: 0.8817
#
# Epoch 24/100
# ----------
# train Loss: 0.0719 Acc: 0.9804
# val Loss: 0.4234 Acc: 0.8710
#
# Epoch 25/100
# ----------
# train Loss: 0.0705 Acc: 0.9801
# val Loss: 0.4668 Acc: 0.8280
#
# Epoch 26/100
# ----------
# train Loss: 0.0809 Acc: 0.9748
# val Loss: 0.4543 Acc: 0.8387
#
# Epoch 27/100
# ----------
# train Loss: 0.0947 Acc: 0.9735
# val Loss: 0.4700 Acc: 0.8602
#
# Epoch 28/100
# ----------
# train Loss: 0.0966 Acc: 0.9708
# val Loss: 0.4874 Acc: 0.8387
#
# Epoch 29/100
# ----------
# train Loss: 0.0868 Acc: 0.9738
# val Loss: 0.4429 Acc: 0.8495
#
# Epoch 30/100
# ----------
# train Loss: 0.0949 Acc: 0.9688
# val Loss: 0.4119 Acc: 0.8387
#
# Epoch 31/100
# ----------
# train Loss: 0.0826 Acc: 0.9751
# val Loss: 0.4828 Acc: 0.8280
#
# Epoch 32/100
# ----------
# train Loss: 0.0904 Acc: 0.9755
# val Loss: 0.4643 Acc: 0.8387
#
# Epoch 33/100
# ----------
# train Loss: 0.0910 Acc: 0.9731
# val Loss: 0.4132 Acc: 0.8280
#
# Epoch 34/100
# ----------
# train Loss: 0.0790 Acc: 0.9755
# val Loss: 0.4902 Acc: 0.8602
#
# Epoch 35/100
# ----------
# train Loss: 0.0732 Acc: 0.9804
# val Loss: 0.4658 Acc: 0.8172
#
# Epoch 36/100
# ----------
# train Loss: 0.0806 Acc: 0.9755
# val Loss: 0.5155 Acc: 0.8602
#
# Epoch 37/100
# ----------
# train Loss: 0.0880 Acc: 0.9791
# val Loss: 0.4558 Acc: 0.8602
#
# Epoch 38/100
# ----------
# train Loss: 0.1021 Acc: 0.9675
# val Loss: 0.4450 Acc: 0.8280
#
# Epoch 39/100
# ----------
# train Loss: 0.0839 Acc: 0.9728
# val Loss: 0.4265 Acc: 0.8387
#
# Epoch 40/100
# ----------
# train Loss: 0.0876 Acc: 0.9741
# val Loss: 0.4357 Acc: 0.8710
#
# Epoch 41/100
# ----------
# train Loss: 0.0972 Acc: 0.9705
# val Loss: 0.5163 Acc: 0.7957
#
# Epoch 42/100
# ----------
# train Loss: 0.0898 Acc: 0.9698
# val Loss: 0.4623 Acc: 0.8602
#
# Epoch 43/100
# ----------
# train Loss: 0.0828 Acc: 0.9771
# val Loss: 0.4565 Acc: 0.8602
#
# Epoch 44/100
# ----------
# train Loss: 0.0898 Acc: 0.9728
# val Loss: 0.4641 Acc: 0.8387
#
# Epoch 45/100
# ----------
# train Loss: 0.0760 Acc: 0.9804
# val Loss: 0.4422 Acc: 0.8280
#
# Epoch 46/100
# ----------
# train Loss: 0.0872 Acc: 0.9748
# val Loss: 0.4392 Acc: 0.8280
#
# Epoch 47/100
# ----------
# train Loss: 0.0809 Acc: 0.9748
# val Loss: 0.4489 Acc: 0.8495
#
# Epoch 48/100
# ----------
# train Loss: 0.0993 Acc: 0.9692
# val Loss: 0.4524 Acc: 0.8387
#
# Epoch 49/100
# ----------
# train Loss: 0.0889 Acc: 0.9745
# val Loss: 0.4243 Acc: 0.8387
#
# Epoch 50/100
# ----------
# train Loss: 0.0828 Acc: 0.9738
# val Loss: 0.4584 Acc: 0.8280
#
# Epoch 51/100
# ----------
# train Loss: 0.0810 Acc: 0.9778
# val Loss: 0.4446 Acc: 0.8280
#
# Epoch 52/100
# ----------
# train Loss: 0.0783 Acc: 0.9791
# val Loss: 0.4309 Acc: 0.8602
#
# Epoch 53/100
# ----------
# train Loss: 0.0877 Acc: 0.9725
# val Loss: 0.4154 Acc: 0.8387
#
# Epoch 54/100
# ----------
# train Loss: 0.0873 Acc: 0.9731
# val Loss: 0.4161 Acc: 0.8387
#
# Epoch 55/100
# ----------
# train Loss: 0.0838 Acc: 0.9731
# val Loss: 0.4595 Acc: 0.8495
#
# Epoch 56/100
# ----------
# train Loss: 0.0784 Acc: 0.9768
# val Loss: 0.4434 Acc: 0.8495
#
# Epoch 57/100
# ----------
# train Loss: 0.0882 Acc: 0.9758
# val Loss: 0.4476 Acc: 0.8495
#
# Epoch 58/100
# ----------
# train Loss: 0.0829 Acc: 0.9745
# val Loss: 0.4857 Acc: 0.8387
#
# Epoch 59/100
# ----------
# train Loss: 0.0888 Acc: 0.9738
# val Loss: 0.4197 Acc: 0.8280
#
# Epoch 60/100
# ----------
# train Loss: 0.0755 Acc: 0.9775
# val Loss: 0.4383 Acc: 0.8495
#
# Epoch 61/100
# ----------
# train Loss: 0.0866 Acc: 0.9728
# val Loss: 0.4778 Acc: 0.8387
#
# Epoch 62/100
# ----------
# train Loss: 0.0862 Acc: 0.9738
# val Loss: 0.4610 Acc: 0.8172
#
# Epoch 63/100
# ----------
# train Loss: 0.0899 Acc: 0.9768
# val Loss: 0.4213 Acc: 0.8495
#
# Epoch 64/100
# ----------
# train Loss: 0.0920 Acc: 0.9705
# val Loss: 0.5275 Acc: 0.8495
#
# Epoch 65/100
# ----------
# train Loss: 0.1079 Acc: 0.9655
# val Loss: 0.4064 Acc: 0.8495
#
# Epoch 66/100
# ----------
# train Loss: 0.0735 Acc: 0.9784
# val Loss: 0.4546 Acc: 0.8387
#
# Epoch 67/100
# ----------
# train Loss: 0.0829 Acc: 0.9755
# val Loss: 0.4372 Acc: 0.8710
#
# Epoch 68/100
# ----------
# train Loss: 0.0769 Acc: 0.9771
# val Loss: 0.4794 Acc: 0.8065
#
# Epoch 69/100
# ----------
# train Loss: 0.0897 Acc: 0.9745
# val Loss: 0.4141 Acc: 0.8387
#
# Epoch 70/100
# ----------
# train Loss: 0.0818 Acc: 0.9761
# val Loss: 0.4045 Acc: 0.8387
#
# Epoch 71/100
# ----------
# train Loss: 0.0912 Acc: 0.9728
# val Loss: 0.4450 Acc: 0.8817
#
# Epoch 72/100
# ----------
# train Loss: 0.0793 Acc: 0.9768
# val Loss: 0.4605 Acc: 0.8172
#
# Epoch 73/100
# ----------
# train Loss: 0.0787 Acc: 0.9775
# val Loss: 0.4271 Acc: 0.8172
#
# Epoch 74/100
# ----------
# train Loss: 0.0834 Acc: 0.9731
# val Loss: 0.4116 Acc: 0.8602
#
# Epoch 75/100
# ----------
# train Loss: 0.0768 Acc: 0.9778
# val Loss: 0.4203 Acc: 0.8387
#
# Epoch 76/100
# ----------
# train Loss: 0.0904 Acc: 0.9708
# val Loss: 0.4681 Acc: 0.8387
#
# Epoch 77/100
# ----------
# train Loss: 0.0836 Acc: 0.9735
# val Loss: 0.4034 Acc: 0.8602
#
# Epoch 78/100
# ----------
# train Loss: 0.0832 Acc: 0.9745
# val Loss: 0.4733 Acc: 0.8172
#
# Epoch 79/100
# ----------
# train Loss: 0.0853 Acc: 0.9725
# val Loss: 0.4999 Acc: 0.8172
#
# Epoch 80/100
# ----------
# train Loss: 0.0915 Acc: 0.9731
# val Loss: 0.4201 Acc: 0.8172
#
# Epoch 81/100
# ----------
# train Loss: 0.0839 Acc: 0.9731
# val Loss: 0.4403 Acc: 0.8280
#
# Epoch 82/100
# ----------
# train Loss: 0.0821 Acc: 0.9741
# val Loss: 0.4646 Acc: 0.8387
#
# Epoch 83/100
# ----------
# train Loss: 0.0851 Acc: 0.9735
# val Loss: 0.4463 Acc: 0.8495
#
# Epoch 84/100
# ----------
# train Loss: 0.0766 Acc: 0.9761
# val Loss: 0.4806 Acc: 0.8065
#
# Epoch 85/100
# ----------
# train Loss: 0.0780 Acc: 0.9761
# val Loss: 0.4262 Acc: 0.8710
#
# Epoch 86/100
# ----------
# train Loss: 0.0857 Acc: 0.9738
# val Loss: 0.4617 Acc: 0.8280
#
# Epoch 87/100
# ----------
# train Loss: 0.0894 Acc: 0.9735
# val Loss: 0.4370 Acc: 0.8710
#
# Epoch 88/100
# ----------
# train Loss: 0.0829 Acc: 0.9751
# val Loss: 0.4102 Acc: 0.8602
#
# Epoch 89/100
# ----------
# train Loss: 0.0745 Acc: 0.9768
# val Loss: 0.4270 Acc: 0.8495
#
# Epoch 90/100
# ----------
# train Loss: 0.0787 Acc: 0.9758
# val Loss: 0.4480 Acc: 0.8280
#
# Epoch 91/100
# ----------
# train Loss: 0.0950 Acc: 0.9705
# val Loss: 0.4448 Acc: 0.8495
#
# Epoch 92/100
# ----------
# train Loss: 0.0703 Acc: 0.9824
# val Loss: 0.4462 Acc: 0.8387
#
# Epoch 93/100
# ----------
# train Loss: 0.0826 Acc: 0.9755
# val Loss: 0.4901 Acc: 0.8387
#
# Epoch 94/100
# ----------
# train Loss: 0.0855 Acc: 0.9731
# val Loss: 0.4178 Acc: 0.8280
#
# Epoch 95/100
# ----------
# train Loss: 0.0872 Acc: 0.9765
# val Loss: 0.4136 Acc: 0.8387
#
# Epoch 96/100
# ----------
# train Loss: 0.0820 Acc: 0.9761
# val Loss: 0.4476 Acc: 0.8495
#
# Epoch 97/100
# ----------
# train Loss: 0.0798 Acc: 0.9748
# val Loss: 0.4634 Acc: 0.8495
#
# Epoch 98/100
# ----------
# train Loss: 0.0842 Acc: 0.9738
# val Loss: 0.4344 Acc: 0.8602
#
# Epoch 99/100
# ----------
# train Loss: 0.0725 Acc: 0.9791
# val Loss: 0.4621 Acc: 0.8602
#
# Epoch 100/100
# ----------
# train Loss: 0.0771 Acc: 0.9741
# val Loss: 0.4526 Acc: 0.8387
#
# Epoch 101/100
# ----------
# train Loss: 0.0827 Acc: 0.9745
# val Loss: 0.4586 Acc: 0.8172
#
# Training complete in 31m 3s
# Best val Acc: 0.881720

# %%
visualize_model(model_ft, 10)
# Out:
# Actual label: 1
# predicted: 0 with 0.0054 probabilities
# predicted: 1 with 0.9945 probabilities
# predicted: 2 with 1e-04 probabilities
# Actual label: 1
# predicted: 0 with 0.0047 probabilities
# predicted: 1 with 0.8241 probabilities
# predicted: 2 with 0.1712 probabilities
# Actual label: 2
# predicted: 0 with 0.0051 probabilities
# predicted: 1 with 0.8825 probabilities
# predicted: 2 with 0.1123 probabilities
# Actual label: 1
# predicted: 0 with 0.0004 probabilities
# predicted: 1 with 0.9988 probabilities
# predicted: 2 with 0.0009 probabilities
# Actual label: 1
# predicted: 0 with 0.0208 probabilities
# predicted: 1 with 0.977 probabilities
# predicted: 2 with 0.0023 probabilities
# Actual label: 0
# predicted: 0 with 0.4329 probabilities
# predicted: 1 with 0.5671 probabilities
# predicted: 2 with 0.0 probabilities
# Actual label: 0
# predicted: 0 with 0.558 probabilities
# predicted: 1 with 0.4416 probabilities
# predicted: 2 with 0.0005 probabilities
# Actual label: 2
# predicted: 0 with 0.1126 probabilities
# predicted: 1 with 0.3498 probabilities
# predicted: 2 with 0.5376 probabilities
# Actual label: 1
# predicted: 0 with 0.0 probabilities
# predicted: 1 with 0.9989 probabilities
# predicted: 2 with 0.001 probabilities
# Actual label: 1
# predicted: 0 with 0.0004 probabilities
# predicted: 1 with 0.9649 probabilities
# predicted: 2 with 0.0347 probabilities

# %%
correct = 0
total = 0
nb_classes = 3
confusion_matrix = torch.zeros(nb_classes, nb_classes)
with torch.no_grad():
    for data in dataloaders['train']:
        images, labels = data[0].cuda(), data[1].cuda()
        outputs = model_ft(images)
        predicted = torch.round(outputs)
        _, predicted = torch.max(outputs, 1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        for t, p in zip(labels.view(-1), predicted.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1
        

print('Accuracy of the network on the %s train images: %d %%' % (total,
    100 * correct / total))

print(confusion_matrix)
b= torch.sum(confusion_matrix, dim=1)
print(confusion_matrix/torch.reshape(b, (-1, 1))) #Normalizing
# Out:
# Accuracy of the network on the 3016 train images: 99 %
# tensor([[3.9400e+02, 5.0000e+00, 1.0000e+00],
#         [3.0000e+00, 2.1770e+03, 4.0000e+00],
#         [0.0000e+00, 3.0000e+00, 4.2900e+02]])
# tensor([[0.9850, 0.0125, 0.0025],
#         [0.0014, 0.9968, 0.0018],
#         [0.0000, 0.0069, 0.9931]])

# %%
correct = 0
total = 0
nb_classes = 3
confusion_matrix = torch.zeros(nb_classes, nb_classes)
with torch.no_grad():
    for data in dataloaders['val']:
        images, labels = data[0].cuda(), data[1].cuda()
        outputs = model_ft(images)
        predicted = torch.round(outputs)
        _, predicted = torch.max(outputs, 1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        for t, p in zip(labels.view(-1), predicted.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1
        

print('Accuracy of the network on the %s val images: %d %%' % (total,
    100 * correct / total))

print(confusion_matrix)
b= torch.sum(confusion_matrix, dim=1)
print(confusion_matrix/torch.reshape(b, (-1, 1))) #Normalizing
# Out:
# Accuracy of the network on the 93 val images: 88 %
# tensor([[ 9.,  3.,  0.],
#         [ 1., 65.,  2.],
#         [ 1.,  4.,  8.]])
# tensor([[0.7500, 0.2500, 0.0000],
#         [0.0147, 0.9559, 0.0294],
#         [0.0769, 0.3077, 0.6154]])

# %%
correct = 0
total = 0
nb_classes = 3
confusion_matrix = torch.zeros(nb_classes, nb_classes)
with torch.no_grad():
    for data in dataloaders['test']:
        images, labels = data[0].cuda(), data[1].cuda()
        outputs = model_ft(images)
        predicted = torch.round(outputs)
        _, predicted = torch.max(outputs, 1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        for t, p in zip(labels.view(-1), predicted.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1
        

print('Accuracy of the network on the %s test images: %d %%' % (total,
    100 * correct / total))

print(confusion_matrix)
b= torch.sum(confusion_matrix, dim=1)
print(confusion_matrix/torch.reshape(b, (-1, 1))) #Normalizing
# Out:
# Accuracy of the network on the 98 test images: 87 %
# tensor([[10.,  3.,  1.],
#         [ 3., 65.,  1.],
#         [ 0.,  4., 11.]])
# tensor([[0.7143, 0.2143, 0.0714],
#         [0.0435, 0.9420, 0.0145],
#         [0.0000, 0.2667, 0.7333]])

# %%
if not os.path.exists('trained models'):
   os.makedirs('trained models')
PATH = './trained models/GoogLeNet-TTVClass3-BestEP%s.pth' %(ep)
torch.save(model_ft.state_dict(), PATH)
