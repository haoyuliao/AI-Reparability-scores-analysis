# %%
# %matplotlib inline
#Reference from https://pytorch.org/

# %%
from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy

plt.ion()   # interactive mode

# %%
# Data augmentation and normalization for training
# Just normalization for validation
'''
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}
'''
data_transforms = {
    'train': transforms.Compose([
        #transforms.RandomResizedCrop(224),
        transforms.Resize([224, 224]),
        transforms.RandomHorizontalFlip(),
        transforms.RandomVerticalFlip(),
        transforms.RandomRotation(180),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize([224, 224]),
        #transforms.Resize(256),
        #transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}


data_transforms = {
    'train': transforms.Compose([
        transforms.Resize([224, 224]),
        transforms.RandomHorizontalFlip(),
        transforms.RandomVerticalFlip(),
        transforms.RandomRotation(180),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize([224, 224]),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}


data_dir = '../AddMoreData061823/Class2/TTV'
l = []
l.append(datasets.ImageFolder(os.path.join(data_dir, 'train'), data_transforms['train']))
l.append(datasets.ImageFolder(os.path.join(data_dir, 'train'), data_transforms['train']))
l.append(datasets.ImageFolder(os.path.join(data_dir, 'train'), data_transforms['train']))
l.append(datasets.ImageFolder(os.path.join(data_dir, 'train'), data_transforms['train']))
#l.append(datasets.ImageFolder(os.path.join(data_dir, 'test'), data_transforms['test']))
image_datasetss = torch.utils.data.ConcatDataset(l)
image_datasets = {}
image_datasets['train'] = image_datasetss
image_datasets['test'] = datasets.ImageFolder(os.path.join(data_dir, 'test'), data_transforms['test'])
image_datasets['val'] = datasets.ImageFolder(os.path.join(data_dir, 'val'), data_transforms['test'])
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=5,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'test', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'test', 'val']}
class_names = image_datasets['test'].classes
print(class_names)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

print(len( image_datasets['train']))
print(len( image_datasets['val']))
print(len( image_datasets['test']))
# Out:
# ['0', '1', '2', '3', '4']
# 3020
# 92
# 98

# %% [markdown]
# Visualize a few images
# ^^^^^^^^^^^^^^^^^^^^^^
# Let's visualize a few training images so as to understand the data
# augmentations.

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

print(class_names)
# Out:
# ['0', '1', '2', '3', '4']

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs+1):
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    #print(outputs)
                    #print(labels)
                    loss = criterion(outputs, labels)
    
                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %% [markdown]
# Visualizing the model predictions
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# Generic function to display predictions for a few images

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['test']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)

            m = nn.Softmax(dim=1)
            proOutput = m(outputs)
            pros = proOutput.detach().cpu().numpy()
            #print(pros)
            #_, preds = torch.max(outputs, 1)
            #pro = torch.max(proOutput, dim=1)[0]
            #_, predsmin = torch.min(outputs, 1)
            #promin = torch.min(proOutput, dim=1)[0]

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                #ax.set_title('predicted: %s with %s probabilities' %(class_names[preds[j]], round(pro[j].item(),4)))
                print('Actual label: %s' %(class_names[labels[j].item()]))
                for jj in range(5):
                    print('predicted: %s with %s probabilities' %(class_names[jj], round(pros[j][jj],4)))
                #print('predicted: %s with %s probabilities' %(class_names[1], round(pros[j][1],4)))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
                
        model.train(mode=was_training)

#visualize_model(model_ft)

# %%
model_ft = models.googlenet(pretrained=True) #load googlenet.

num_ftrs = model_ft.fc.in_features

# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, 5)

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %% [markdown]
# Train and evaluate
# ^^^^^^^^^^^^^^^^^^
#
# It should take around 15-25 min on CPU. On GPU though, it takes less than a
# minute.

# %%
ep = 100
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=ep)
# Out:
# Epoch 1/100
# ----------
# train Loss: 1.2648 Acc: 0.4533
# val Loss: 1.1254 Acc: 0.5326
#
# Epoch 2/100
# ----------
# train Loss: 0.9940 Acc: 0.5924
# val Loss: 0.9569 Acc: 0.5978
#
# Epoch 3/100
# ----------
# train Loss: 0.7673 Acc: 0.7007
# val Loss: 0.9961 Acc: 0.6304
#
# Epoch 4/100
# ----------
# train Loss: 0.6294 Acc: 0.7619
# val Loss: 1.0738 Acc: 0.7609
#
# Epoch 5/100
# ----------
# train Loss: 0.5085 Acc: 0.8113
# val Loss: 0.9377 Acc: 0.7174
#
# Epoch 6/100
# ----------
# train Loss: 0.4242 Acc: 0.8536
# val Loss: 0.8405 Acc: 0.7391
#
# Epoch 7/100
# ----------
# train Loss: 0.3730 Acc: 0.8656
# val Loss: 0.9937 Acc: 0.6522
#
# Epoch 8/100
# ----------
# train Loss: 0.2473 Acc: 0.9156
# val Loss: 0.8946 Acc: 0.7174
#
# Epoch 9/100
# ----------
# train Loss: 0.2142 Acc: 0.9272
# val Loss: 0.9283 Acc: 0.7065
#
# Epoch 10/100
# ----------
# train Loss: 0.2348 Acc: 0.9195
# val Loss: 0.8536 Acc: 0.7609
#
# Epoch 11/100
# ----------
# train Loss: 0.1873 Acc: 0.9381
# val Loss: 0.8020 Acc: 0.7391
#
# Epoch 12/100
# ----------
# train Loss: 0.1706 Acc: 0.9421
# val Loss: 0.8050 Acc: 0.7174
#
# Epoch 13/100
# ----------
# train Loss: 0.1589 Acc: 0.9513
# val Loss: 0.8148 Acc: 0.7500
#
# Epoch 14/100
# ----------
# train Loss: 0.1663 Acc: 0.9454
# val Loss: 0.7872 Acc: 0.7500
#
# Epoch 15/100
# ----------
# train Loss: 0.1603 Acc: 0.9454
# val Loss: 0.8217 Acc: 0.7283
#
# Epoch 16/100
# ----------
# train Loss: 0.1527 Acc: 0.9513
# val Loss: 0.7974 Acc: 0.7500
#
# Epoch 17/100
# ----------
# train Loss: 0.1589 Acc: 0.9444
# val Loss: 0.8066 Acc: 0.7283
#
# Epoch 18/100
# ----------
# train Loss: 0.1593 Acc: 0.9460
# val Loss: 0.8060 Acc: 0.7500
#
# Epoch 19/100
# ----------
# train Loss: 0.1631 Acc: 0.9477
# val Loss: 0.8160 Acc: 0.7500
#
# Epoch 20/100
# ----------
# train Loss: 0.1532 Acc: 0.9533
# val Loss: 0.8049 Acc: 0.7717
#
# Epoch 21/100
# ----------
# train Loss: 0.1496 Acc: 0.9553
# val Loss: 0.8150 Acc: 0.7609
#
# Epoch 22/100
# ----------
# train Loss: 0.1418 Acc: 0.9566
# val Loss: 0.8177 Acc: 0.7283
#
# Epoch 23/100
# ----------
# train Loss: 0.1576 Acc: 0.9470
# val Loss: 0.7707 Acc: 0.7609
#
# Epoch 24/100
# ----------
# train Loss: 0.1486 Acc: 0.9546
# val Loss: 0.8614 Acc: 0.7500
#
# Epoch 25/100
# ----------
# train Loss: 0.1611 Acc: 0.9477
# val Loss: 0.8302 Acc: 0.7717
#
# Epoch 26/100
# ----------
# train Loss: 0.1436 Acc: 0.9546
# val Loss: 0.7946 Acc: 0.7500
#
# Epoch 27/100
# ----------
# train Loss: 0.1490 Acc: 0.9487
# val Loss: 0.7814 Acc: 0.7609
#
# Epoch 28/100
# ----------
# train Loss: 0.1526 Acc: 0.9500
# val Loss: 0.7836 Acc: 0.7717
#
# Epoch 29/100
# ----------
# train Loss: 0.1526 Acc: 0.9503
# val Loss: 0.8338 Acc: 0.7717
#
# Epoch 30/100
# ----------
# train Loss: 0.1486 Acc: 0.9523
# val Loss: 0.8155 Acc: 0.7391
#
# Epoch 31/100
# ----------
# train Loss: 0.1708 Acc: 0.9487
# val Loss: 0.8034 Acc: 0.7500
#
# Epoch 32/100
# ----------
# train Loss: 0.1610 Acc: 0.9444
# val Loss: 0.8498 Acc: 0.7717
#
# Epoch 33/100
# ----------
# train Loss: 0.1483 Acc: 0.9493
# val Loss: 0.8084 Acc: 0.7609
#
# Epoch 34/100
# ----------
# train Loss: 0.1524 Acc: 0.9487
# val Loss: 0.8584 Acc: 0.7391
#
# Epoch 35/100
# ----------
# train Loss: 0.1691 Acc: 0.9411
# val Loss: 0.7871 Acc: 0.7609
#
# Epoch 36/100
# ----------
# train Loss: 0.1537 Acc: 0.9464
# val Loss: 0.7943 Acc: 0.7609
#
# Epoch 37/100
# ----------
# train Loss: 0.1640 Acc: 0.9397
# val Loss: 0.8605 Acc: 0.7500
#
# Epoch 38/100
# ----------
# train Loss: 0.1786 Acc: 0.9414
# val Loss: 0.8212 Acc: 0.7391
#
# Epoch 39/100
# ----------
# train Loss: 0.1510 Acc: 0.9500
# val Loss: 0.8679 Acc: 0.7717
#
# Epoch 40/100
# ----------
# train Loss: 0.1478 Acc: 0.9510
# val Loss: 0.8586 Acc: 0.7717
#
# Epoch 41/100
# ----------
# train Loss: 0.1396 Acc: 0.9550
# val Loss: 0.8027 Acc: 0.7826
#
# Epoch 42/100
# ----------
# train Loss: 0.1696 Acc: 0.9474
# val Loss: 0.7842 Acc: 0.7500
#
# Epoch 43/100
# ----------
# train Loss: 0.1699 Acc: 0.9434
# val Loss: 0.8010 Acc: 0.7717
#
# Epoch 44/100
# ----------
# train Loss: 0.1490 Acc: 0.9503
# val Loss: 0.8087 Acc: 0.7500
#
# Epoch 45/100
# ----------
# train Loss: 0.1635 Acc: 0.9470
# val Loss: 0.8063 Acc: 0.7609
#
# Epoch 46/100
# ----------
# train Loss: 0.1542 Acc: 0.9474
# val Loss: 0.7645 Acc: 0.7609
#
# Epoch 47/100
# ----------
# train Loss: 0.1508 Acc: 0.9467
# val Loss: 0.8061 Acc: 0.7609
#
# Epoch 48/100
# ----------
# train Loss: 0.1620 Acc: 0.9440
# val Loss: 0.8358 Acc: 0.7500
#
# Epoch 49/100
# ----------
# train Loss: 0.1648 Acc: 0.9493
# val Loss: 0.8230 Acc: 0.7609
#
# Epoch 50/100
# ----------
# train Loss: 0.1514 Acc: 0.9470
# val Loss: 0.7760 Acc: 0.7391
#
# Epoch 51/100
# ----------
# train Loss: 0.1365 Acc: 0.9579
# val Loss: 0.8378 Acc: 0.7609
#
# Epoch 52/100
# ----------
# train Loss: 0.1539 Acc: 0.9510
# val Loss: 0.8226 Acc: 0.7609
#
# Epoch 53/100
# ----------
# train Loss: 0.1669 Acc: 0.9444
# val Loss: 0.8266 Acc: 0.7500
#
# Epoch 54/100
# ----------
# train Loss: 0.1356 Acc: 0.9553
# val Loss: 0.8138 Acc: 0.7609
#
# Epoch 55/100
# ----------
# train Loss: 0.1554 Acc: 0.9474
# val Loss: 0.8366 Acc: 0.7935
#
# Epoch 56/100
# ----------
# train Loss: 0.1524 Acc: 0.9487
# val Loss: 0.8016 Acc: 0.7500
#
# Epoch 57/100
# ----------
# train Loss: 0.1499 Acc: 0.9517
# val Loss: 0.8111 Acc: 0.7826
#
# Epoch 58/100
# ----------
# train Loss: 0.1612 Acc: 0.9457
# val Loss: 0.8419 Acc: 0.7283
#
# Epoch 59/100
# ----------
# train Loss: 0.1556 Acc: 0.9457
# val Loss: 0.7965 Acc: 0.7609
#
# Epoch 60/100
# ----------
# train Loss: 0.1480 Acc: 0.9520
# val Loss: 0.8037 Acc: 0.7500
#
# Epoch 61/100
# ----------
# train Loss: 0.1616 Acc: 0.9493
# val Loss: 0.7828 Acc: 0.7500
#
# Epoch 62/100
# ----------
# train Loss: 0.1593 Acc: 0.9477
# val Loss: 0.8156 Acc: 0.7717
#
# Epoch 63/100
# ----------
# train Loss: 0.1630 Acc: 0.9470
# val Loss: 0.8037 Acc: 0.7717
#
# Epoch 64/100
# ----------
# train Loss: 0.1434 Acc: 0.9523
# val Loss: 0.8017 Acc: 0.7609
#
# Epoch 65/100
# ----------
# train Loss: 0.1408 Acc: 0.9560
# val Loss: 0.8107 Acc: 0.7826
#
# Epoch 66/100
# ----------
# train Loss: 0.1511 Acc: 0.9536
# val Loss: 0.7951 Acc: 0.7717
#
# Epoch 67/100
# ----------
# train Loss: 0.1426 Acc: 0.9543
# val Loss: 0.8694 Acc: 0.7826
#
# Epoch 68/100
# ----------
# train Loss: 0.1585 Acc: 0.9500
# val Loss: 0.8165 Acc: 0.7500
#
# Epoch 69/100
# ----------
# train Loss: 0.1548 Acc: 0.9483
# val Loss: 0.7989 Acc: 0.7609
#
# Epoch 70/100
# ----------
# train Loss: 0.1606 Acc: 0.9470
# val Loss: 0.8024 Acc: 0.7609
#
# Epoch 71/100
# ----------
# train Loss: 0.1497 Acc: 0.9513
# val Loss: 0.8163 Acc: 0.7500
#
# Epoch 72/100
# ----------
# train Loss: 0.1489 Acc: 0.9500
# val Loss: 0.8146 Acc: 0.7500
#
# Epoch 73/100
# ----------
# train Loss: 0.1484 Acc: 0.9530
# val Loss: 0.7655 Acc: 0.7500
#
# Epoch 74/100
# ----------
# train Loss: 0.1516 Acc: 0.9513
# val Loss: 0.8224 Acc: 0.7826
#
# Epoch 75/100
# ----------
# train Loss: 0.1472 Acc: 0.9540
# val Loss: 0.8129 Acc: 0.7717
#
# Epoch 76/100
# ----------
# train Loss: 0.1367 Acc: 0.9583
# val Loss: 0.8097 Acc: 0.7717
#
# Epoch 77/100
# ----------
# train Loss: 0.1607 Acc: 0.9460
# val Loss: 0.8238 Acc: 0.7500
#
# Epoch 78/100
# ----------
# train Loss: 0.1480 Acc: 0.9483
# val Loss: 0.8056 Acc: 0.7391
#
# Epoch 79/100
# ----------
# train Loss: 0.1459 Acc: 0.9513
# val Loss: 0.8521 Acc: 0.7609
#
# Epoch 80/100
# ----------
# train Loss: 0.1515 Acc: 0.9487
# val Loss: 0.8039 Acc: 0.7609
#
# Epoch 81/100
# ----------
# train Loss: 0.1439 Acc: 0.9546
# val Loss: 0.8675 Acc: 0.7500
#
# Epoch 82/100
# ----------
# train Loss: 0.1605 Acc: 0.9460
# val Loss: 0.8096 Acc: 0.7391
#
# Epoch 83/100
# ----------
# train Loss: 0.1406 Acc: 0.9573
# val Loss: 0.8098 Acc: 0.7391
#
# Epoch 84/100
# ----------
# train Loss: 0.1493 Acc: 0.9503
# val Loss: 0.7931 Acc: 0.7609
#
# Epoch 85/100
# ----------
# train Loss: 0.1465 Acc: 0.9543
# val Loss: 0.8320 Acc: 0.7935
#
# Epoch 86/100
# ----------
# train Loss: 0.1649 Acc: 0.9411
# val Loss: 0.8029 Acc: 0.7391
#
# Epoch 87/100
# ----------
# train Loss: 0.1436 Acc: 0.9490
# val Loss: 0.8364 Acc: 0.7500
#
# Epoch 88/100
# ----------
# train Loss: 0.1460 Acc: 0.9556
# val Loss: 0.8381 Acc: 0.7500
#
# Epoch 89/100
# ----------
# train Loss: 0.1492 Acc: 0.9540
# val Loss: 0.8065 Acc: 0.7500
#
# Epoch 90/100
# ----------
# train Loss: 0.1605 Acc: 0.9464
# val Loss: 0.8284 Acc: 0.7717
#
# Epoch 91/100
# ----------
# train Loss: 0.1525 Acc: 0.9487
# val Loss: 0.8743 Acc: 0.7826
#
# Epoch 92/100
# ----------
# train Loss: 0.1661 Acc: 0.9427
# val Loss: 0.8348 Acc: 0.7391
#
# Epoch 93/100
# ----------
# train Loss: 0.1584 Acc: 0.9480
# val Loss: 0.8036 Acc: 0.7283
#
# Epoch 94/100
# ----------
# train Loss: 0.1569 Acc: 0.9450
# val Loss: 0.7900 Acc: 0.7391
#
# Epoch 95/100
# ----------
# train Loss: 0.1498 Acc: 0.9497
# val Loss: 0.7921 Acc: 0.7717
#
# Epoch 96/100
# ----------
# train Loss: 0.1717 Acc: 0.9444
# val Loss: 0.8108 Acc: 0.7391
#
# Epoch 97/100
# ----------
# train Loss: 0.1523 Acc: 0.9503
# val Loss: 0.8319 Acc: 0.7174
#
# Epoch 98/100
# ----------
# train Loss: 0.1462 Acc: 0.9483
# val Loss: 0.8157 Acc: 0.7283
#
# Epoch 99/100
# ----------
# train Loss: 0.1606 Acc: 0.9477
# val Loss: 0.8985 Acc: 0.7609
#
# Epoch 100/100
# ----------
# train Loss: 0.1755 Acc: 0.9377
# val Loss: 0.8069 Acc: 0.7500
#
# Epoch 101/100
# ----------
# train Loss: 0.1532 Acc: 0.9493
# val Loss: 0.7984 Acc: 0.7391
#
# Training complete in 31m 14s
# Best val Acc: 0.793478

# %%
visualize_model(model_ft, 10)
# Out:
# Actual label: 3
# predicted: 0 with 0.0017 probabilities
# predicted: 1 with 0.0 probabilities
# predicted: 2 with 0.0005 probabilities
# predicted: 3 with 0.9978 probabilities
# predicted: 4 with 1e-04 probabilities
# Actual label: 3
# predicted: 0 with 0.0004 probabilities
# predicted: 1 with 0.0114 probabilities
# predicted: 2 with 0.0838 probabilities
# predicted: 3 with 0.865 probabilities
# predicted: 4 with 0.0394 probabilities
# Actual label: 4
# predicted: 0 with 0.0028 probabilities
# predicted: 1 with 0.7938 probabilities
# predicted: 2 with 0.0078 probabilities
# predicted: 3 with 0.0009 probabilities
# predicted: 4 with 0.1947 probabilities
# Actual label: 0
# predicted: 0 with 0.6428 probabilities
# predicted: 1 with 0.0994 probabilities
# predicted: 2 with 0.0939 probabilities
# predicted: 3 with 0.1479 probabilities
# predicted: 4 with 0.0161 probabilities
# Actual label: 2
# predicted: 0 with 0.0031 probabilities
# predicted: 1 with 0.0196 probabilities
# predicted: 2 with 0.7374 probabilities
# predicted: 3 with 0.2395 probabilities
# predicted: 4 with 0.0004 probabilities
# Actual label: 2
# predicted: 0 with 0.0049 probabilities
# predicted: 1 with 0.1639 probabilities
# predicted: 2 with 0.2242 probabilities
# predicted: 3 with 0.5273 probabilities
# predicted: 4 with 0.0797 probabilities
# Actual label: 3
# predicted: 0 with 0.0 probabilities
# predicted: 1 with 0.0 probabilities
# predicted: 2 with 0.0004 probabilities
# predicted: 3 with 0.9995 probabilities
# predicted: 4 with 0.0 probabilities
# Actual label: 3
# predicted: 0 with 0.0002 probabilities
# predicted: 1 with 0.0065 probabilities
# predicted: 2 with 0.0414 probabilities
# predicted: 3 with 0.9499 probabilities
# predicted: 4 with 0.0019 probabilities
# Actual label: 1
# predicted: 0 with 0.0019 probabilities
# predicted: 1 with 0.9898 probabilities
# predicted: 2 with 0.0037 probabilities
# predicted: 3 with 0.0046 probabilities
# predicted: 4 with 0.0 probabilities
# Actual label: 2
# predicted: 0 with 0.0 probabilities
# predicted: 1 with 0.0004 probabilities
# predicted: 2 with 0.9514 probabilities
# predicted: 3 with 0.0481 probabilities
# predicted: 4 with 1e-04 probabilities

# %%
correct = 0
total = 0
nb_classes = 5
confusion_matrix = torch.zeros(nb_classes, nb_classes)
with torch.no_grad():
    for data in dataloaders['train']:
        images, labels = data[0].cuda(), data[1].cuda()
        outputs = model_ft(images)
        predicted = torch.round(outputs)
        _, predicted = torch.max(outputs, 1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        for t, p in zip(labels.view(-1), predicted.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1
        

print('Accuracy of the network on the %s train images: %d %%' % (total,
    100 * correct / total))

print(confusion_matrix)
b= torch.sum(confusion_matrix, dim=1)
print(confusion_matrix/torch.reshape(b, (-1, 1))) #Normalizing
# Out:
# Accuracy of the network on the 3020 train images: 99 %
# tensor([[2.1200e+02, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [0.0000e+00, 5.4400e+02, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [0.0000e+00, 1.0000e+00, 1.0600e+03, 2.0000e+00, 5.0000e+00],
#         [1.0000e+00, 0.0000e+00, 1.0000e+00, 1.0500e+03, 0.0000e+00],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.4400e+02]])
# tensor([[1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [0.0000e+00, 9.3633e-04, 9.9251e-01, 1.8727e-03, 4.6816e-03],
#         [9.5057e-04, 0.0000e+00, 9.5057e-04, 9.9810e-01, 0.0000e+00],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]])

# %%
correct = 0
total = 0
nb_classes = 5
confusion_matrix = torch.zeros(nb_classes, nb_classes)
with torch.no_grad():
    for data in dataloaders['val']:
        images, labels = data[0].cuda(), data[1].cuda()
        outputs = model_ft(images)
        predicted = torch.round(outputs)
        _, predicted = torch.max(outputs, 1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        for t, p in zip(labels.view(-1), predicted.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1
        

print('Accuracy of the network on the %s val images: %d %%' % (total,
    100 * correct / total))

print(confusion_matrix)
b= torch.sum(confusion_matrix, dim=1)
print(confusion_matrix/torch.reshape(b, (-1, 1))) #Normalizing
# Out:
# Accuracy of the network on the 92 val images: 79 %
# tensor([[ 5.,  0.,  1.,  0.,  0.],
#         [ 0., 12.,  1.,  4.,  0.],
#         [ 1.,  6., 23.,  3.,  0.],
#         [ 0.,  0.,  0., 31.,  1.],
#         [ 0.,  0.,  1.,  1.,  2.]])
# tensor([[0.8333, 0.0000, 0.1667, 0.0000, 0.0000],
#         [0.0000, 0.7059, 0.0588, 0.2353, 0.0000],
#         [0.0303, 0.1818, 0.6970, 0.0909, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.9688, 0.0312],
#         [0.0000, 0.0000, 0.2500, 0.2500, 0.5000]])

# %%
correct = 0
total = 0
nb_classes = 5
confusion_matrix = torch.zeros(nb_classes, nb_classes)
with torch.no_grad():
    for data in dataloaders['test']:
        images, labels = data[0].cuda(), data[1].cuda()
        outputs = model_ft(images)
        predicted = torch.round(outputs)
        _, predicted = torch.max(outputs, 1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        for t, p in zip(labels.view(-1), predicted.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1
        

print('Accuracy of the network on the %s test images: %d %%' % (total,
    100 * correct / total))

print(confusion_matrix)
b= torch.sum(confusion_matrix, dim=1)
print(confusion_matrix/torch.reshape(b, (-1, 1))) #Normalizing
# Out:
# Accuracy of the network on the 98 test images: 78 %
# tensor([[ 4.,  0.,  1.,  3.,  0.],
#         [ 0., 16.,  1.,  0.,  0.],
#         [ 0.,  2., 22.,  9.,  1.],
#         [ 0.,  1.,  0., 33.,  0.],
#         [ 0.,  1.,  2.,  0.,  2.]])
# tensor([[0.5000, 0.0000, 0.1250, 0.3750, 0.0000],
#         [0.0000, 0.9412, 0.0588, 0.0000, 0.0000],
#         [0.0000, 0.0588, 0.6471, 0.2647, 0.0294],
#         [0.0000, 0.0294, 0.0000, 0.9706, 0.0000],
#         [0.0000, 0.2000, 0.4000, 0.0000, 0.4000]])

# %%
if not os.path.exists('trained models'):
   os.makedirs('trained models')
PATH = './trained models/GoogLeNet-TTVClass2-BestEP%s.pth' %(ep)
torch.save(model_ft.state_dict(), PATH)
